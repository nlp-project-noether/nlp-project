# %%
import pandas as pd
import numpy as np
import time
import os
from typing import Dict, List, Optional, Union, cast
from bs4 import BeautifulSoup
import requests

# %%
def get_readme():
    filename = "data.json"

    if os.path.isfile(filename):
        return pd.read_json(filename)
    
    else:
        hrefs = [] 
        for p in range(1,14):
            url = f'https://github.com/search?p={p}&q=Hacktoberfest&type=Repositories'
            response = requests.get(url)
            soup = BeautifulSoup(response.text,'html.parser')
            links = soup.find_all("a", {"class": "v-align-middle"})
            links = [l['href'] for l in links]
            hrefs.append(links)
            time.sleep(15)
        flat_list = [item for sublist in hrefs for item in sublist]  
        return flat_list

# %%
get_readme()
# Out:
#                                         repo          language  \
# 0             /AliceWonderland/hacktoberfest              HTML
# 1               /fineanmol/Hacktoberfest2022            Python
# 2         /keshavsingh4522/hacktoberfest2021  Jupyter Notebook
# 3           /ossamamehmood/Hacktoberfest2022  Jupyter Notebook
# 4          /tarunsinghofficial/HacktoberFest              Java
# ..                                       ...               ...
# 125            /rituburman/hacktoberfest2020               C++
# 126       /akanksha-raghav/Hacktoberfest2021  Jupyter Notebook
# 127                 /TARANG0503/DSA-Practice               C++
# 128  /rathoresrikant/HacktoberFestContribute               C++
# 129        /Shreyasheeetal20/HACKTOBERFEST22              HTML
#
#                                        readme_contents
# 0    # 🎃 HacktoberFest Starter Project 🎃\n\n** __Oc...
# 1    Hacktoberfest-2022\n\n**Checkout this Project ...
# 2    <div align="centre">\n    <b>dont contribute i...
# 3    # HacktoberFest 2022 `OPEN FIRST` Pull Request...
# 4    # HacktoberFest- Contribute to Open-Source.\n\...
# ..                                                 ...
# 125  # Hacktoberfest For Everyone\nYou can start co...
# 126  # Hacktoberfest2021\nHacktoberfest® is open to...
# 127  ## DSA Practice\nThis project is a collection ...
# 128  Please note that the contributions made to thi...
# 129  # HACKTOBERFEST22\nThis repository is for ever...
#
# [130 rows x 3 columns]

# %%
json = pd.read_json('data.json')

# %%
df= pd.DataFrame(json)

# %%
df
# Out:
#                                         repo          language  \
# 0             /AliceWonderland/hacktoberfest              HTML
# 1               /fineanmol/Hacktoberfest2022            Python
# 2         /keshavsingh4522/hacktoberfest2021  Jupyter Notebook
# 3           /ossamamehmood/Hacktoberfest2022  Jupyter Notebook
# 4          /tarunsinghofficial/HacktoberFest              Java
# ..                                       ...               ...
# 125            /rituburman/hacktoberfest2020               C++
# 126       /akanksha-raghav/Hacktoberfest2021  Jupyter Notebook
# 127                 /TARANG0503/DSA-Practice               C++
# 128  /rathoresrikant/HacktoberFestContribute               C++
# 129        /Shreyasheeetal20/HACKTOBERFEST22              HTML
#
#                                        readme_contents
# 0    # 🎃 HacktoberFest Starter Project 🎃\n\n** __Oc...
# 1    Hacktoberfest-2022\n\n**Checkout this Project ...
# 2    <div align="centre">\n    <b>dont contribute i...
# 3    # HacktoberFest 2022 `OPEN FIRST` Pull Request...
# 4    # HacktoberFest- Contribute to Open-Source.\n\...
# ..                                                 ...
# 125  # Hacktoberfest For Everyone\nYou can start co...
# 126  # Hacktoberfest2021\nHacktoberfest® is open to...
# 127  ## DSA Practice\nThis project is a collection ...
# 128  Please note that the contributions made to thi...
# 129  # HACKTOBERFEST22\nThis repository is for ever...
#
# [130 rows x 3 columns]

# %%
df.language.value_counts()
# Out:
# Jupyter Notebook    4
# C++                 4
# Python              3
# Java                3
# HTML                2
# JavaScript          1
# SCSS                1
# Name: language, dtype: int64

# %%
jn= df[df.language== 'Jupyter Notebook']

# %%
jn
# Out:
#                                                 repo          language  \
# 2                 /keshavsingh4522/hacktoberfest2021  Jupyter Notebook
# 3                   /ossamamehmood/Hacktoberfest2022  Jupyter Notebook
# 15                    /Sangwan5688/Hacktoberfest2021  Jupyter Notebook
# 19                   /atyant-yadav/Hacktoberfest2020  Jupyter Notebook
# 23                         /thisisshub/HacktoberFest  Jupyter Notebook
# 27               /abhishekdoifode1/Hacktoberfest2021  Jupyter Notebook
# 35               /harshitbansal373/hacktoberfest2020  Jupyter Notebook
# 52                   /namishkhanna/hacktoberfest2020  Jupyter Notebook
# 61      /SR-Sunny-Raj/Hacktoberfest2022-for-everyone  Jupyter Notebook
# 65                      /Edwinliby/Hacktoberfest2022  Jupyter Notebook
# 70           /Hansajith98/hacktoberfest2021-Excluded  Jupyter Notebook
# 74    /bhaveshlohana/HacktoberFest2020-Contributions  Jupyter Notebook
# 78                  /rohansaini886/Hacktoberfest2022  Jupyter Notebook
# 79                      /py3-coder/Hacktober_Repo_22  Jupyter Notebook
# 81             /DSC-COEA-Ambajogai/Hacktoberfest2020  Jupyter Notebook
# 85           /SpooderManEXE/Hacktoberfest2020-Expert  Jupyter Notebook
# 99                    /LordDraagonLive/hacktoberfest  Jupyter Notebook
# 102                    /dscgecbsp/Hacktoberfest-2021  Jupyter Notebook
# 117  /AnanyaDas162/Code-Collection-Hacktoberfest2022  Jupyter Notebook
# 118                                 /aryangulati/DEV  Jupyter Notebook
# 123                  /namishkhanna/hacktoberfest2021  Jupyter Notebook
# 126               /akanksha-raghav/Hacktoberfest2021  Jupyter Notebook
#
#                                        readme_contents
# 2    <div align="centre">\n    <b>dont contribute i...
# 3    # HacktoberFest 2022 `OPEN FIRST` Pull Request...
# 15   # Hacktoberfest2021\n![Hacktoberfest](https://...
# 19   # Hacktoberfest2020\n\nA repo for new open sou...
# 23   ⚠️ This project won't be participating in Hack...
# 27   # Hacktoberfest2020\nThis Repo is created by A...
# 35   <p align="center">\n    <a href="https://hackt...
# 52   # Hacktober Fest\n![Hacktoberfest 2020](hackto...
# 61   ![image](https://uno-website-assets.s3.amazona...
# 65   <h1 align="center">HacktoberFest 2022</h1>\n\n...
# 70    # Excluded project Repository &#x1F534; &#x1F...
# 74   ## Disclaimer:\n![image](https://user-images.g...
# 78   <h1 align="center"> <img src= "https://octodex...
# 79   \n# Hacktoberfest 2022 `OPEN Pull Request` - `...
# 81   \n# HacktoberFest 2020\n![image](https://user-...
# 85   # UPDATE: No longer merging PR's. Thank You fo...
# 99   \n# hacktoberfest\nParticipate in Hacktoberfes...
# 102  # Hacktoberfest-2021\n<img src='https://github...
# 117  # Code-Collection-hacktoberfest2022\nThis repo...
# 118  <h1 align="center"> Hacktoberfest2020 🎉</h1>\n...
# 123  # Hacktober Fest 2021\n![Hacktoberfest 2021](h...
# 126  # Hacktoberfest2021\nHacktoberfest® is open to...

# %%
import nltk
import unicodedata
import re

def clean_text(text, extra_stopwords=[]):
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english') + extra_stopwords
    clean_text = (unicodedata.normalize('NFKD', text)
                   .encode('ascii', 'ignore')
                   .decode('utf-8', 'ignore')
                   .lower())
    words = re.sub(r'[^\w\s___]', '', clean_text).split()
    words = re.sub(r'_', '',' '.join(words)).split(' ')
    words = [w for w in words if len(w)<25]
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
words
# Out:
# ['hacktoberfest',
#  'starter',
#  'project',
#  'oct',
#  '24th',
#  '2017',
#  'update',
#  'repo',
#  'temporarily',
#  'not',
#  'merging',
#  'new',
#  'prs',
#  'contributorsmd',
#  'file',
#  'sorted',
#  'thanks',
#  'patience',
#  'use',
#  'project',
#  'make',
#  'first',
#  'contribution',
#  'open',
#  'source',
#  'project',
#  'github',
#  'practice',
#  'making',
#  'first',
#  'pull',
#  'request',
#  'public',
#  'repository',
#  'real',
#  'thing',
#  'celebrate',
#  'getting',
#  'involved',
#  'open',
#  'source',
#  'community',
#  'completing',
#  'simple',
#  'task',
#  'project',
#  'repository',
#  'open',
#  'member',
#  'github',
#  'community',
#  'member',
#  'may',
#  'contribute',
#  'project',
#  'without',
#  'collaborator',
#  'hacktoberfest',
#  'monthlong',
#  'celebration',
#  'october',
#  '1st',
#  '31st',
#  'sponsored',
#  'digital',
#  'get',
#  'people',
#  'involved',
#  'open',
#  'create',
#  'first',
#  'pull',
#  'request',
#  'public',
#  'repository',
#  'github',
#  'contribute',
#  'open',
#  'source',
#  'developer',
#  'community',
#  'contribute',
#  'project',
#  '3',
#  'quick',
#  'painless',
#  'way',
#  'contribute',
#  'project',
#  'add',
#  'name',
#  'contributorsmd',
#  'file',
#  'add',
#  'profile',
#  'page',
#  'profile',
#  'directory',
#  'create',
#  'simple',
#  'hello',
#  'world',
#  'script',
#  'language',
#  'choice',
#  'choose',
#  'one',
#  '3',
#  'make',
#  'pull',
#  'request',
#  'work',
#  'wait',
#  'merged',
#  'getting',
#  'started',
#  'fork',
#  'repository',
#  'click',
#  'fork',
#  'button',
#  'top',
#  'right',
#  'page',
#  'click',
#  'profile',
#  'image',
#  'clone',
#  'fork',
#  'local',
#  'machine',
#  'markdown',
#  'git',
#  'clone',
#  'create',
#  'branch',
#  'markdown',
#  'git',
#  'checkout',
#  'b',
#  'branchname',
#  'make',
#  'change',
#  'choose',
#  'task',
#  'commit',
#  'push',
#  'markdown',
#  'git',
#  'add',
#  'git',
#  'commit',
#  'commit',
#  'message',
#  'git',
#  'push',
#  'origin',
#  'branchname',
#  'create',
#  'new',
#  'pull',
#  'request',
#  'forked',
#  'repository',
#  'click',
#  'new',
#  'pull',
#  'request',
#  'button',
#  'located',
#  'top',
#  'repo',
#  'wait',
#  'pr',
#  'review',
#  'merge',
#  'approval',
#  'star',
#  'repository',
#  'fun',
#  'choose',
#  'task',
#  '1',
#  'add',
#  'name',
#  'add',
#  'name',
#  'contributorsmd',
#  'file',
#  'using',
#  'convention',
#  'markdown',
#  'name',
#  'namegithub',
#  'link',
#  'place',
#  'city',
#  'state',
#  'country',
#  'bio',
#  'github',
#  'github',
#  'account',
#  'namegithub',
#  'link',
#  '2',
#  'add',
#  'profile',
#  'page',
#  'add',
#  'yournamemd',
#  'file',
#  'profile',
#  'directory',
#  'use',
#  'combination',
#  'content',
#  'markdown',
#  'youd',
#  'like',
#  'example',
#  'markdown',
#  'name',
#  'location',
#  'citycountry',
#  'academic',
#  'school',
#  'interest',
#  'thing',
#  'like',
#  'development',
#  'inventor',
#  'pillow',
#  'project',
#  'projectgithub',
#  'link',
#  'short',
#  'description',
#  'profile',
#  'link',
#  'namegithub',
#  'link',
#  '3',
#  'create',
#  'hello',
#  'world',
#  'script',
#  'add',
#  'helloworldyourusernamexx',
#  'script',
#  'script',
#  'directory',
#  'language',
#  'choice',
#  'example',
#  'javascript',
#  'language',
#  'javascript',
#  'env',
#  'nodejs',
#  'author',
#  'alice',
#  'chuang',
#  'github',
#  'consoleloghello',
#  'world',
#  'name',
#  'file',
#  'helloworldyourusernamexx',
#  'eg',
#  'dont',
#  'forget',
#  'include',
#  'comment',
#  'seen',
#  'feel',
#  'free',
#  'include',
#  'additional',
#  'information',
#  'language',
#  'choose',
#  'comment',
#  'like',
#  'link',
#  'helpful',
#  'introduction',
#  'tutorial',
#  'helloworld',
#  'example',
#  'bonus',
#  'see',
#  'profile',
#  'submitted',
#  'fellow',
#  'coder',
#  'around',
#  'globe',
#  'kathmandu',
#  'copenhagen',
#  'discover',
#  'obscure',
#  'new',
#  'trending',
#  'language',
#  'brainfuck',
#  'groovy',
#  'check',
#  'creative',
#  'way',
#  'print',
#  'hello',
#  'world',
#  'string',
#  'reference',
#  'link',
#  'great',
#  'tutorial',
#  'creating',
#  'first',
#  'pull',
#  'request',
#  'roshan',
#  'managing',
#  'forked',
#  'repo',
#  'syncing',
#  'fork',
#  'keep',
#  'fork',
#  'synced',
#  'checkout',
#  'list',
#  'readme',
#  'example',
#  'awesome',
#  'readme',
#  'githubflavored',
#  'markdown',
#  'additional',
#  'reference',
#  'added',
#  'contributor',
#  'github',
#  'license',
#  'explained',
#  'hacktoberfest2022',
#  'checkout',
#  'project',
#  'well',
#  'annoying',
#  'hacktoberfest',
#  'github',
#  'submit',
#  'pr',
#  'new',
#  'repo',
#  'merging',
#  'pr',
#  'current',
#  'repo',
#  'alot',
#  'conflict',
#  'merging',
#  'conflict',
#  'get',
#  'resolved',
#  'hacktoberfest',
#  'live',
#  'beginnerfriendly',
#  'project',
#  'help',
#  'get',
#  'started',
#  'dont',
#  'know',
#  'start',
#  'feel',
#  'free',
#  'watch',
#  'video',
#  'linked',
#  'read',
#  'contribution',
#  'rule',
#  'happy',
#  'learning',
#  '3',
#  'p',
#  'star',
#  'share',
#  'repository',
#  'fun',
#  'hacktoberfest',
#  '2022',
#  'event',
#  'video',
#  'hacktoberfest',
#  'pull',
#  'request',
#  'merge',
#  'conflict',
#  'contribution',
#  'rule',
#  'allowed',
#  'make',
#  'pull',
#  'request',
#  'break',
#  'rule',
#  'merge',
#  'add',
#  'build',
#  'step',
#  'eg',
#  'npm',
#  'install',
#  'want',
#  'keep',
#  'simple',
#  'static',
#  'site',
#  'remove',
#  'content',
#  'stylingcode',
#  'pretty',
#  'ugly',
#  'stupid',
#  'big',
#  'small',
#  'long',
#  'work',
#  'add',
#  'name',
#  'contributorslist',
#  'file',
#  'try',
#  'keep',
#  'pull',
#  'request',
#  'small',
#  'minimize',
#  'merge',
#  'conflict',
#  'getting',
#  'started',
#  'fork',
#  'repo',
#  'button',
#  'top',
#  'clone',
#  'local',
#  'machine',
#  'terminal',
#  'git',
#  'clone',
#  'navigate',
#  'project',
#  'directory',
#  'terminal',
#  'cd',
#  'hacktoberfest2022',
#  'create',
#  'new',
#  'branch',
#  'markdown',
#  'git',
#  'checkout',
#  'b',
#  'mynewbranch',
#  'add',
#  'name',
#  'markdown',
#  'git',
#  'add',
#  'commit',
#  'change',
#  'markdown',
#  'git',
#  'commit',
#  'relevant',
#  'message',
#  'push',
#  'markdown',
#  'git',
#  'push',
#  'origin',
#  'mynewbranch',
#  'create',
#  'new',
#  'pull',
#  'request',
#  'forked',
#  'repository',
#  'br',
#  'avoid',
#  'conflict',
#  'syncing',
#  'fork',
#  'easy',
#  'way',
#  'avoid',
#  'conflict',
#  'add',
#  'upstream',
#  'git',
#  'repo',
#  'pr',
#  'may',
#  'merged',
#  'youre',
#  'working',
#  'branchfork',
#  'terminal',
#  'git',
#  'remote',
#  'add',
#  'upstream',
#  'verify',
#  'new',
#  'remote',
#  'added',
#  'typing',
#  'terminal',
#  'git',
#  'remote',
#  'v',
#  'pull',
#  'new',
#  'change',
#  'parent',
#  'repo',
#  'simply',
#  'run',
#  'terminal',
#  'git',
#  'merge',
#  'upstreammaster',
#  'give',
#  'eventual',
#  'conflict',
#  'allow',
#  'easily',
#  'solve',
#  'repo',
#  'good',
#  'idea',
#  'use',
#  'frequently',
#  'commits',
#  'make',
#  'sure',
#  'repo',
#  'date',
#  'parent',
#  'information',
#  'syncing',
#  'fork',
#  'read',
#  'article',
#  'swag',
#  'hacktoberfest',
#  'many',
#  'candidate',
#  'get',
#  'attracted',
#  'towards',
#  'hacktoberfest',
#  'get',
#  'swag',
#  '4',
#  'successfully',
#  'merged',
#  'pull',
#  'request',
#  '2021',
#  'eligible',
#  'get',
#  'hacktoberfest',
#  'tshirt',
#  'sticker',
#  'doorstep',
#  'libpimg',
#  'width400',
#  'height225',
#  'stylewidth',
#  '400px',
#  'height',
#  '225px',
#  'alttshirt',
#  'imageappimg',
#  'width400',
#  'height225',
#  'stylewidth',
#  '400px',
#  'height',
#  '225px',
#  'altstickers',
#  'imagep',
#  'bli',
#  'faq',
#  'frequently',
#  'asked',
#  'question',
#  'contribute',
#  'anyone',
#  'github',
#  'account',
#  'signed',
#  'getting',
#  'paid',
#  'sadly',
#  'think',
#  '100',
#  'unofficial',
#  'fun',
#  'fame',
#  'glory',
#  'two',
#  'programmer',
#  'india',
#  'love',
#  'open',
#  'source',
#  'hacktoberfest',
#  'want',
#  'make',
#  'easier',
#  'people',
#  'get',
#  'started',
#  'hacktoberfest',
#  'open',
#  'source',
#  'using',
#  'digitalocean',
#  'know',
#  'javascript',
#  'suck',
#  'server',
#  'use',
#  'nowhttpszeitconow',
#  'instead',
#  'come',
#  'closer',
#  'text',
#  'saying',
#  'dont',
#  'come',
#  'closer',
#  'left',
#  'side',
#  'home',
#  'tab',
#  'nope',
#  'many',
#  'pull',
#  'request',
#  'pr',
#  'must',
#  'made',
#  'want',
#  'get',
#  'awesome',
#  'tshirt',
#  'hacktoberfest',
#  '2022',
#  '4',
#  'track',
#  'progress',
#  'get',
#  'awesome',
#  'shirt',
#  'hacktoberfest',
#  '2022',
#  'go',
#  'check',
#  'stats',
#  'right',
#  'top',
#  'duration',
#  'hacktoberfest',
#  '2022',
#  '1st',
#  'october',
#  '31st',
#  'october',
#  '2022',
#  'event',
#  'open',
#  'source',
#  'community',
#  'engagement',
#  'learn',
#  'contribute',
#  'open',
#  'source',
#  'best',
#  'merge',
#  'much',
#  'possible',
#  'everyone',
#  'however',
#  'time',
#  'limited',
#  'merge',
#  'conflict',
#  'horrible',
#  'astonished',
#  '3',
#  'br',
#  'top',
#  'contributor',
#  'p',
#  'aligncentera',
#  'img',
#  'ap',
#  'div',
#  'aligncentre',
#  'bdont',
#  'contribute',
#  'repo',
#  'contribute',
#  'mentioned',
#  'repob',
#  'div',
#  'special',
#  'note',
#  'everyone',
#  'py',
#  'always',
#  'make',
#  '4',
#  'pull',
#  'request',
#  'let',
#  'made',
#  '4',
#  'pull',
#  'request',
#  'different',
#  'project',
#  'one',
#  'project',
#  'excluded',
#  'hackoctoberfest',
#  'event',
#  'pull',
#  'request',
#  'count',
#  'remains',
#  '3',
#  'valid',
#  'pull',
#  'request',
#  'project',
#  'excluded',
#  'fail',
#  'make',
#  '4',
#  'pull',
#  'request',
#  'cant',
#  'get',
#  'swag',
#  'tshirts',
#  'recommend',
#  'make',
#  'pull',
#  'request',
#  'repo',
#  'saffest',
#  'side',
#  'keep',
#  'mind',
#  'repo',
#  'hacktoberfest',
#  'topic',
#  'p',
#  'aligncenter',
#  'img',
#  'width30',
#  'p',
#  'h1',
#  'aligncenter',
#  'hacktoberfest',
#  '2021',
#  'h1',
#  'div',
#  'aligncenter',
#  'img',
#  'althacktober',
#  'badge',
#  'img',
#  'altstar',
#  'badge',
#  'img',
#  'altcontributions',
#  'altpull',
#  'request',
#  'badgea',
#  'altgithub',
#  'contributor',
#  'altlicense',
#  'badgea',
#  'div',
#  'hacktoberfest',
#  'encourages',
#  'participation',
#  'open',
#  'source',
#  'community',
#  'grows',
#  'bigger',
#  'every',
#  'year',
#  'complete',
#  '2021',
#  'challenge',
#  'earn',
#  'limited',
#  'edition',
#  'tshirt',
#  'register',
#  'hacktoberfest',
#  'make',
#  'four',
#  'pull',
#  'request',
#  'pr',
#  'october',
#  '1st31st',
#  'grab',
#  'free',
#  'swag',
#  'upload',
#  'code',
#  'repository',
#  'particular',
#  'section',
#  'folder',
#  'present',
#  'create',
#  'folder',
#  'repos',
#  'contribution',
#  'repository',
#  'issue',
#  'pull',
#  'request',
#  'fork',
#  'new',
#  'repo',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'github',
#  'rule',
#  'dont',
#  'use',
#  'filthy',
#  'word',
#  'welcome',
#  'beginner',
#  'people',
#  'community',
#  'github',
#  'contribution',
#  'rule',
#  'pull',
#  'request',
#  'submitted',
#  'optedin',
#  'repository',
#  'github',
#  'gitlab',
#  'pull',
#  'request',
#  'must',
#  'contain',
#  'commits',
#  'made',
#  'maintainer',
#  'report',
#  'pull',
#  'request',
#  'spam',
#  'counted',
#  'toward',
#  'participation',
#  'hacktoberfest',
#  'maintainer',
#  'report',
#  'behavior',
#  'thats',
#  'line',
#  'project',
#  'code',
#  'conduct',
#  'ineligible',
#  'participate',
#  'get',
#  'shirt',
#  'must',
#  'make',
#  'four',
#  'approved',
#  'pull',
#  'request',
#  'pr',
#  'optedin',
#  'project',
#  'october',
#  '131',
#  'time',
#  'zone',
#  'year',
#  'first',
#  '50000',
#  'participant',
#  'earn',
#  'tshirt',
#  'step',
#  'adding',
#  'name',
#  '1',
#  'fork',
#  'repo',
#  '2',
#  'edit',
#  'contributersmd',
#  'file',
#  '3',
#  'add',
#  'name',
#  'also',
#  'link',
#  'github',
#  'profile',
#  '4',
#  'make',
#  'pull',
#  'request',
#  'contributor',
#  'allcontributorsliststart',
#  'remove',
#  'modify',
#  'section',
#  'prettierignorestart',
#  'markdownlintdisable',
#  'table',
#  'trtd',
#  'aligncentera',
#  'width100px',
#  'altkbdbr',
#  'subbaman',
#  'guptabsubabr',
#  'titlecode',
#  'computer',
#  'td',
#  'td',
#  'aligncentera',
#  'width100px',
#  'altkbdbr',
#  'subbaman',
#  'kumarbsubabr',
#  'titlecode',
#  'computer',
#  'td',
#  'td',
#  'aligncentera',
#  'width100px',
#  'altkbdbr',
#  'subbsubhanshumgbsubabr',
#  'titlecode',
#  'computer',
#  'td',
#  'td',
#  'aligncentera',
#  'width100px',
#  ...]

# %%
df['clean'] = df.readme_contents.apply(clean_text)

# %%
df
# Out:
#                                         repo          language  \
# 0             /AliceWonderland/hacktoberfest              HTML
# 1               /fineanmol/Hacktoberfest2022            Python
# 2         /keshavsingh4522/hacktoberfest2021  Jupyter Notebook
# 3           /ossamamehmood/Hacktoberfest2022  Jupyter Notebook
# 4          /tarunsinghofficial/HacktoberFest              Java
# ..                                       ...               ...
# 125            /rituburman/hacktoberfest2020               C++
# 126       /akanksha-raghav/Hacktoberfest2021  Jupyter Notebook
# 127                 /TARANG0503/DSA-Practice               C++
# 128  /rathoresrikant/HacktoberFestContribute               C++
# 129        /Shreyasheeetal20/HACKTOBERFEST22              HTML
#
#                                        readme_contents  \
# 0    # 🎃 HacktoberFest Starter Project 🎃\n\n** __Oc...
# 1    Hacktoberfest-2022\n\n**Checkout this Project ...
# 2    <div align="centre">\n    <b>dont contribute i...
# 3    # HacktoberFest 2022 `OPEN FIRST` Pull Request...
# 4    # HacktoberFest- Contribute to Open-Source.\n\...
# ..                                                 ...
# 125  # Hacktoberfest For Everyone\nYou can start co...
# 126  # Hacktoberfest2021\nHacktoberfest® is open to...
# 127  ## DSA Practice\nThis project is a collection ...
# 128  Please note that the contributions made to thi...
# 129  # HACKTOBERFEST22\nThis repository is for ever...
#
#                                                  clean
# 0    [hacktoberfest, starter, project, oct, 24th, 2...
# 1    [hacktoberfest2022, checkout, project, well, a...
# 2    [div, aligncentre, bdont, contribute, repo, co...
# 3    [hacktoberfest, 2022, open, first, pull, reque...
# 4    [hacktoberfest, contribute, opensource, create...
# ..                                                 ...
# 125  [hacktoberfest, everyone, start, contributing,...
# 126  [hacktoberfest2021, hacktoberfest, open, every...
# 127  [dsa, practice, project, collection, datastruc...
# 128  [please, note, contribution, made, repository,...
# 129  [hacktoberfest22, repository, everyone, want, ...
#
# [130 rows x 4 columns]

# %%
def jupy_replace(df):
    
    '''
    This function goes through the `language` column, and replaces it with the 
    second most used language from the repo. 
    '''
    
    new_lang = ['C++', 'C++','C++','python','python','python', 'python', 'python',
                 'python', 'python', 'python', 'python', 'python', 'C++',
                 'python', 'C++', 'python', 'python', 'python', 'HTML', 'python',
                 'Javascript']
    repo_mod = pd.DataFrame(df[df['language']== 'Jupyter Notebook']['repo'])
    repo_mod['new_lang'] = new_lang
    for x in repo_mod.index:
        df.loc[x, 'language'] = repo_mod.loc[x, 'new_lang']
    return df

# %%
df= jupy_replace(df)

# %%
df.language= df.language.str.lower()

# %%
df.language.value_counts()
# Out:
# c++           34
# python        29
# html          23
# javascript    10
# java           9
# css            4
# c              3
# scss           1
# php            1
# ruby           1
# ejs            1
# Name: language, dtype: int64

# %%
df.language= df.language.str.strip()

# %%
def clean_lang(df):
    df.language = df.language.str.lower()
    invalid = list(set(list(df.language.value_counts().index))-set(['c++', 'python', 'html']))
    invalid_index = df[df.language.isin(invalid)]['language'].index
    df.loc[invalid_index,'language']='other'
    return df

# %%
clean_lang(df)
# Out:
#                                         repo language  \
# 0             /AliceWonderland/hacktoberfest     html
# 1               /fineanmol/Hacktoberfest2022   python
# 2         /keshavsingh4522/hacktoberfest2021      c++
# 3           /ossamamehmood/Hacktoberfest2022      c++
# 4          /tarunsinghofficial/HacktoberFest    other
# ..                                       ...      ...
# 125            /rituburman/hacktoberfest2020      c++
# 126       /akanksha-raghav/Hacktoberfest2021    other
# 127                 /TARANG0503/DSA-Practice      c++
# 128  /rathoresrikant/HacktoberFestContribute      c++
# 129        /Shreyasheeetal20/HACKTOBERFEST22     html
#
#                                        readme_contents  \
# 0    # 🎃 HacktoberFest Starter Project 🎃\n\n** __Oc...
# 1    Hacktoberfest-2022\n\n**Checkout this Project ...
# 2    <div align="centre">\n    <b>dont contribute i...
# 3    # HacktoberFest 2022 `OPEN FIRST` Pull Request...
# 4    # HacktoberFest- Contribute to Open-Source.\n\...
# ..                                                 ...
# 125  # Hacktoberfest For Everyone\nYou can start co...
# 126  # Hacktoberfest2021\nHacktoberfest® is open to...
# 127  ## DSA Practice\nThis project is a collection ...
# 128  Please note that the contributions made to thi...
# 129  # HACKTOBERFEST22\nThis repository is for ever...
#
#                                                  clean
# 0    [hacktoberfest, starter, project, oct, 24th, 2...
# 1    [hacktoberfest2022, checkout, project, well, a...
# 2    [div, aligncentre, bdont, contribute, repo, co...
# 3    [hacktoberfest, 2022, open, first, pull, reque...
# 4    [hacktoberfest, contribute, opensource, create...
# ..                                                 ...
# 125  [hacktoberfest, everyone, start, contributing,...
# 126  [hacktoberfest2021, hacktoberfest, open, every...
# 127  [dsa, practice, project, collection, datastruc...
# 128  [please, note, contribution, made, repository,...
# 129  [hacktoberfest22, repository, everyone, want, ...
#
# [130 rows x 4 columns]

# %%
df.language.value_counts()
# Out:
# c++       34
# other     30
# python    29
# html      23
# Name: language, dtype: int64
